# %%
import requests
from lxml import html
import pandas as pd

# 레시피 URL
recipe_id = 1942052 # 예 : 두부 베이컨 야채전
url = "https://www.10000recipe.com/recipe/"+str(recipe_id)

# 요청; 크롬 드라이브 설정
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

response = requests.get(url, headers=headers)
response.encoding = 'utf-8'  # 한글 인코딩 설정

# HTML 파싱
tree = html.fromstring(response.content)

# 데이터를 저장할 리스트 생성
recipe_data = []

# XPath를 사용하여 데이터 추출 및 저장
for i in range(1, 20):  # 레시피 단계 최대 20개 단계까지 시도
    step = tree.xpath(f'//*[@id="stepdescr{i}"]/text()')
    img = tree.xpath(f'//*[@id="stepimg{i}"]/img/@src')
    
    if step:
        for text in step:
            text_cleaned = text.strip()
            if text_cleaned:
                recipe_data.append({
                    'recipe_id': recipe_id,
                    'recipe_num': i,
                    'recipe_text': text_cleaned,
                    'recipe_img_url': img[0] if img else None
                })
    else:
        break

# 데이터프레임 생성
recipe_df = pd.DataFrame(recipe_data)
recipe_df
# Out:
#    recipe_id  recipe_num                                        recipe_text  \
# 0    1942052           1  양배추, 당근, 베이컨은 채 썹니다. 베이컨은 조금 굵게(약 0.5cm로 썹니다.)...
# 1    1942052           2  두부는 면보에 넣어 물기를 제거합니다. 그릇에 두부, 파, 당근, 양배추, 게란을넣...
# 2    1942052           3  부침가루 1/4컵, 물 4큰술, 베이컨, 소금을 넣고 다시 한번더 섞어 줍니다. 저...
# 3    1942052           4                    기름을 두르고 조금 도톰하게 넣어 앞, 뒤 구워 줍니다.
# 4    1942052           5  먹음직스럽게 구워졌죠. 이렇게만 먹어도 맛나지만, 저는 여기에 간장소스를 만들어 같...
# 5    1942052           6  간장 1/4컵, 설탕 2 1/2큰술, 우스타소스, 정종 1큰술을 넣고 끓입니다. 소...
# 6    1942052           7  불을 끄고 녹말물(녹말 1큰술 + 물 1큰술)을 넣고 섞어 줍니다. 다시 불을 켜고...
# 7    1942052           8  소스를 두부부침개 위에 곁들여서 드시거나, 그릇에 각각 담아 곁들여 드셔도 좋을 듯...
#
#                                       recipe_img_url
# 0  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 1  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 2  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 3  https://recipe1.ezmember.co.kr/cache/recipe/20...
# ...

# %%
from IPython.display import Image, display, HTML

# HTML 테이블 형태로 이미지 표시
html_content = ""
for url in recipe_df['recipe_img_url']:
    if url:
        html_content += f'<img src="{url}" style="width:300px; margin:10px"/><br>'

display(HTML(html_content))
# Out:
# <img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/980d53e41d4a9d571728a1ef84ffc7451.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/126a5cc39a15c54437da82950c66cbeb1.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/c1f5ce7f3d23784df9cf4880484247f91.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/4255b661875826f793e2da4e954465aa1.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/50d2c475cf149db58efa3dff652afbf11.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/cefe2e1e8a64c2a875aab433249f4d651.jpg" style="width:300px; margin:10px"/><br><img src="https://recipe1.ezmember.co.kr/cache/recipe/2015/08/17/37a3ebb1072ce9b6e1a6b42ae39cd6b31.jpg" style="width:300px; margin:10px"/><br><img
# ...
